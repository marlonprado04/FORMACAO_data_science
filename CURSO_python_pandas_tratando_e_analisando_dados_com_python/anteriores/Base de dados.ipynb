# %% [markdown]
# # Relatório de Análise I

# %% [markdown]
# ## Importando base de dados

# %%
import pandas as pd

pd.read_csv('dados/aluguel.csv', sep = ';')
# Out:
#               Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0      Apartamento               Centro        1      0       0    15   800.0
# 1      Apartamento         Higienópolis        1      0       0    48   800.0
# 2      Apartamento             Cachambi        2      0       0    50  1300.0
# 3      Apartamento               Grajaú        2      1       0    70  1500.0
# 4      Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
# ...            ...                  ...      ...    ...     ...   ...     ...
# 19826    Quitinete               Glória        1      0       0    10   400.0
# 19827    Quitinete             Flamengo        1      0       0    23   900.0
# 19828    Quitinete               Centro        1      0       0    24  1100.0
# 19829    Quitinete           Copacabana        1      0       0    22  1500.0
# 19830    Quitinete               Centro        0      0       0    27   800.0
#
# ...

# %%
dados = pd.read_csv("dados/aluguel.csv", sep = ";")

# %%
dados
# Out:
#               Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0      Apartamento               Centro        1      0       0    15   800.0
# 1      Apartamento         Higienópolis        1      0       0    48   800.0
# 2      Apartamento             Cachambi        2      0       0    50  1300.0
# 3      Apartamento               Grajaú        2      1       0    70  1500.0
# 4      Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
# ...            ...                  ...      ...    ...     ...   ...     ...
# 19826    Quitinete               Glória        1      0       0    10   400.0
# 19827    Quitinete             Flamengo        1      0       0    23   900.0
# 19828    Quitinete               Centro        1      0       0    24  1100.0
# 19829    Quitinete           Copacabana        1      0       0    22  1500.0
# 19830    Quitinete               Centro        0      0       0    27   800.0
#
# ...

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.info
# Out:
# <bound method DataFrame.info of               Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0      Apartamento               Centro        1      0       0    15   800.0
# 1      Apartamento         Higienópolis        1      0       0    48   800.0
# 2      Apartamento             Cachambi        2      0       0    50  1300.0
# 3      Apartamento               Grajaú        2      1       0    70  1500.0
# 4      Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
# ...            ...                  ...      ...    ...     ...   ...     ...
# 19826    Quitinete               Glória        1      0       0    10   400.0
# 19827    Quitinete             Flamengo        1      0       0    23   900.0
# 19828    Quitinete               Centro        1      0       0    24  1100.0
# 19829    Quitinete           Copacabana        1      0       0    22  1500.0
# 19830    Quitinete               Centro        0      0       0    27   800.0
#
# ...

# %%
dados.info
# Out:
# <bound method DataFrame.info of               Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0      Apartamento               Centro        1      0       0    15   800.0
# 1      Apartamento         Higienópolis        1      0       0    48   800.0
# 2      Apartamento             Cachambi        2      0       0    50  1300.0
# 3      Apartamento               Grajaú        2      1       0    70  1500.0
# 4      Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
# ...            ...                  ...      ...    ...     ...   ...     ...
# 19826    Quitinete               Glória        1      0       0    10   400.0
# 19827    Quitinete             Flamengo        1      0       0    23   900.0
# 19828    Quitinete               Centro        1      0       0    24  1100.0
# 19829    Quitinete           Copacabana        1      0       0    22  1500.0
# 19830    Quitinete               Centro        0      0       0    27   800.0
#
# ...

# %%
dados.head(10)
# Out:
#           Tipo                   Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0  Apartamento                   Centro        1      0       0    15   800.0
# 1  Apartamento             Higienópolis        1      0       0    48   800.0
# 2  Apartamento                 Cachambi        2      0       0    50  1300.0
# 3  Apartamento                   Grajaú        2      1       0    70  1500.0
# 4  Apartamento      Lins de Vasconcelos        3      1       1    90  1500.0
# 5  Apartamento               Copacabana        1      0       1    40  2000.0
# 6  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 7  Apartamento          Barra da Tijuca        2      1       1    67  1700.0
# 8  Apartamento                   Tijuca        2      1       0   110  1900.0
# 9  Apartamento                   Olaria        3      1       0    68  1000.0
#
#    Condominio   IPTU  Valor m2 Tipo Agregado
# 0       390.0   20.0     53.33   Apartamento
# ...

# %% [markdown]
# ## Informações gerais sobre a base de dados

# %%
dados.dtypes
# Out:
# Tipo              object
# Bairro            object
# Quartos            int64
# Vagas              int64
# Suites             int64
# Area               int64
# Valor            float64
# Condominio       float64
# IPTU             float64
# Valor m2         float64
# Tipo Agregado     object
# dtype: object

# %%
# Atribuindo nome à coluna: "Tipos de Dados"
tipos_de_dados = pd.DataFrame(dados.dtypes, columns=mns = ["Tipos de Dados"])

# %%
# Atribuindo nome às linhas: Variáveis

tipos_de_dados.columns.name = "Variáveis"

# %%
tipos_de_dados
# Out:
# Variáveis     Tipos de Dados
# Tipo                  object
# Bairro                object
# Quartos                int64
# Vagas                  int64
# Suites                 int64
# Area                   int64
# Valor                float64
# Condominio           float64
# IPTU                 float64
# Valor m2             float64
# Tipo Agregado         object

# %%
dados.shape
# Out:
# (19831, 11)

# %%
print("A base de dados apresenta {} registros (imóveis) e {} variáveis".format(dados.shape[0], dados.shape[1]))
# Out:
# A base de dados apresenta 19831 registros (imóveis) e 11 variáveis

# %%
import pandas as pd
data = [['Fulano', 12, 7.0, True],
        ['Sicrano', 15, 3.5, False], 
        ['Beltrano', 18, 9.3, True]]
dados = pd.DataFrame(data, 
        columns = ['Aluno', 'Idade', 'Nota', 'Aprovado'])
dados
# Out:
#       Aluno  Idade  Nota  Aprovado
# 0    Fulano     12   7.0      True
# 1   Sicrano     15   3.5     False
# 2  Beltrano     18   9.3      True

# %%
tipos_de_dados = pd.DataFrame(dados.dtypes)
tipos_de_dados.columns = 'Variáveis'
tipos_de_dados
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 2>()
#       1 tipos_de_dados = pd.DataFrame(dados.dtypes)
# ----> 2 tipos_de_dados.columns = 'Variáveis'
#       3 tipos_de_dados
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
#    5587     object.__getattribute__(self, name)
# -> 5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#    5590     pass
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:768, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
# --> 768     labels = ensure_index(labels)
#     769     self._mgr.set_axis(axis, labels)
# ...
